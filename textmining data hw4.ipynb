# %%
from time import sleep
from selenium import webdriver
import instascrape
import pandas as pd
from selenium.webdriver import Chrome 
from instascrape import Profile, scrape_posts
from instascrape import *

# %%
webdriver = Chrome(r"C:\Users\raina\Downloads\chromedriver_win32 (1)\chromedriver.exe")

# %%
headers = {
    "user-agent": "Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Mobile Safari/537.36 Edg/87.0.664.57",
    "cookie": "sessionid=7246354813%3AQvU8N3teJxDgX8%3A7;"
}
tag = Profile('preventcovid19')
tag.scrape(headers=headers)

# %%
posts = tag.get_posts(webdriver=webdriver, login_first=True)

# %%
scraped_posts = scrape_posts(posts, headers=headers, pause=10, silent=True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-eae3712fcf33> in <module>
# ----> 1 scraped_posts = scrape_posts(posts, headers=headers, pause=10, silent=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\instascrape\scrapers\scrape_tools.py in scrape_posts(posts, session, webdriver, limit, headers, pause, on_exception, silent, inplace)
#     177         temporary_post = copy.deepcopy(post)
#     178         try:
# --> 179             post.scrape(session=session, webdriver=webdriver, headers=headers)
#     180             scraped_posts.append(post)
#     181         except Exception as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\instascrape\scrapers\post.py in scrape(self, mapping, keys, exclude, headers, inplace, session, webdriver)
#      78                             inplace=inplace,
#      79                             session=session,
# ...

# %%
scraped_posts
# Out:
# ([<Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
#   <Post>,
# ...

# %%
posts_df[["upload_date", "likes"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-d01866bfee0a> in <module>
# ----> 1 posts_df[["upload_date", "likes"]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ...
